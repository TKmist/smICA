# %% [markdown]
# ## Credits
#
# smICA was developed by
# Tomasz Kalwarczyk (tkalwarczyk@ichf.edu.pl)
# Institute of Physical Chemistry PAS
# With the contribution of Antoni Lis, Institute of Physical Chemistry PAS
#
# #### Acknowledgements  <br>
# This work was funded by the Polish Science Fund within the framework of the Virtual Research Institute; grant WIB-1/2020-O11 - WIB_HERO.
