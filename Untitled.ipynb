# %%
import pandas as pd
import numpy as np
import pickle
import os

# %%
path = 'EXTRACT_AND_FILTER_PTU/samples/cell11-1317.pkl'
# !ls $path
# Out:
# EXTRACT_AND_FILTER_PTU/samples/cell11-1317.pkl

# %%
with open(path, 'rb') as file:
    pkl = pickle.load(file)

# %%
a = pkl['lifetimes_1']
b = pkl['intensity_1']
type(a),type(b)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
Channels = list(pkl.keys())
Channels = [f for f in Channels if f.startswith('export_df')]
Channels = [ch[-1] for ch in Channels]
Channels
# Out:
# ['1', '2']
